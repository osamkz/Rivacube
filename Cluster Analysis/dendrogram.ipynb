# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %%
# データ生成
# data_labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# df = pd.DataFrame(np.random.rand(100*10).reshape(10,100), index = data_labels) # 乱数で10行100列のデータを模擬
data = pd.read_csv("2020_21.csv")
labels = data["Country/Region"]
data_labels = labels.values.tolist()
df = data.drop('Country/Region',axis=1)


# クラスタリング（ウォード法、ユークリッド距離）
Z = linkage(df, method = "ward", metric = "euclidean")

# デンドログラム図の描画
fig = plt.figure()

dendrogram(Z,
labels = data_labels, # データラベルの設定
orientation = 'right', # デンドログラム図を横向きにする
          ) #color_threshold = 4) # デンドログラム図の色分けの閾値
plt.show()

# %%
# データ生成
data = pd.read_csv("cluster_analysis_before.csv")
labels = data["Country/Region"]
data_labels = labels.values.tolist()
df = data.drop('Country/Region',axis=1)


# クラスタリング（ウォード法、ユークリッド距離）
Z = linkage(df, method = "ward", metric = "euclidean")

# デンドログラム図の描画
fig = plt.figure()

dendrogram(Z,
labels = data_labels, # データラベルの設定
orientation = 'right', # デンドログラム図を横向きにする
          ) #color_threshold = 4) # デンドログラム図の色分けの閾値
plt.show()
